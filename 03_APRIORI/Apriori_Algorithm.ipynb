# %%
import pandas as pd
import numpy as np
import seaborn as sns
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Assignment-1_Data.csv",delimiter=';')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("Assignment-1_Data.csv",delimiter=';')
#       2 df.head()
#
# File D:\Development\PythonProjects\venv_311_7\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File D:\Development\PythonProjects\venv_311_7\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File D:\Development\PythonProjects\venv_311_7\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File D:\Development\PythonProjects\venv_311_7\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File D:\Development\PythonProjects\venv_311_7\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Assignment-1_Data.csv'

# %% [markdown]
# # Yeni Bölüm

# %%
df.shape
# Out:
# (522064, 7)

# %%
#veri özeti alınır
df.describe(include='all')
# Out:
#           BillNo                            Itemname       Quantity  \
# count   522064.0                              520609  522064.000000
# unique   21665.0                                4185            NaN
# top     573585.0  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq      1114.0                                2269            NaN
# mean         NaN                                 NaN      10.090435
# std          NaN                                 NaN     161.110525
# min          NaN                                 NaN   -9600.000000
# 25%          NaN                                 NaN       1.000000
# 50%          NaN                                 NaN       3.000000
# 75%          NaN                                 NaN      10.000000
# max          NaN                                 NaN   80995.000000
#
#                     Date   Price     CustomerID         Country
# count             522064  522064  388023.000000          522064
# unique             19641    1285            NaN              30
# top     31.10.2011 14:41    1,25            NaN  United Kingdom
# freq                1114   48778            NaN          487622
# mean                 NaN     NaN   15316.931710             NaN
# std                  NaN     NaN    1721.846964             NaN
# min                  NaN     NaN   12346.000000             NaN
# 25%                  NaN     NaN   13950.000000             NaN
# 50%                  NaN     NaN   15265.000000             NaN
# 75%                  NaN     NaN   16837.000000             NaN
# max                  NaN     NaN   18287.000000             NaN

# %%
df.dtypes
# Out:
# BillNo         object
# Itemname       object
# Quantity        int64
# Date           object
# Price          object
# CustomerID    float64
# Country        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522064 entries, 0 to 522063
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   BillNo      522064 non-null  object
#  1   Itemname    520609 non-null  object
#  2   Quantity    522064 non-null  int64
#  3   Date        522064 non-null  object
#  4   Price       522064 non-null  object
#  5   CustomerID  388023 non-null  float64
#  6   Country     522064 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 27.9+ MB

# %%
#hangi nitelikte toplam kaç eksik veri olduğu bulunur
df.isna().sum()
# Out:
# BillNo             0
# Itemname        1455
# Quantity           0
# Date               0
# Price              0
# CustomerID    134041
# Country            0
# dtype: int64

# %%
# Itemname niteliğine ait kayıp değerler silinir.
df.drop(df[df['Itemname'].isna()].index,inplace=True)

# %%
#hangi nitelikten kaç adet eksik veri olduğu bulunur
print(df.isnull().sum())
bs=df.columns[df.isnull().any()]

bs_index=list(map(lambda col:df.columns.get_loc(col),bs))
# Out:
# BillNo             0
# Itemname           0
# Quantity           0
# Date               0
# Price              0
# CustomerID    132586
# Country            0
# dtype: int64

# %%
df[df.Itemname.isna()]
# Out:
# Empty DataFrame
# Columns: [BillNo, Itemname, Quantity, Date, Price, CustomerID, Country]
# Index: []

# %%
df.drop(df[df['Itemname'].isna()].index,inplace=True)

# %%
df["Itemname"]=df["Itemname"].fillna(df["Itemname"].mode())

# %%
df.shape
# Out:
# (520609, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 520609 entries, 0 to 522063
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   BillNo      520609 non-null  object
#  1   Itemname    520609 non-null  object
#  2   Quantity    520609 non-null  int64
#  3   Date        520609 non-null  object
#  4   Price       520609 non-null  object
#  5   CustomerID  388023 non-null  float64
#  6   Country     520609 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 31.8+ MB

# %%
df[df['CustomerID'].isna()]
# Out:
#         BillNo                         Itemname  Quantity              Date  \
# 1410    536544  DECORATIVE ROSE BATHROOM BOTTLE         1  01.12.2010 14:32
# 1411    536544  DECORATIVE CATS BATHROOM BOTTLE         2  01.12.2010 14:32
# 1412    536544                POLKADOT RAIN HAT         4  01.12.2010 14:32
# 1413    536544            RAIN PONCHO RETROSPOT         2  01.12.2010 14:32
# 1414    536544               VINTAGE SNAP CARDS         9  01.12.2010 14:32
# ...        ...                              ...       ...               ...
# 521695  581498          JUMBO BAG RED RETROSPOT         5  09.12.2011 10:26
# 521696  581498   JUMBO  BAG BAROQUE BLACK WHITE         4  09.12.2011 10:26
# 521697  581498    LADIES & GENTLEMEN METAL SIGN         1  09.12.2011 10:26
# 521698  581498                S/4 CACTI CANDLES         1  09.12.2011 10:26
# 521699  581498                   DOTCOM POSTAGE         1  09.12.2011 10:26
#
#           Price  CustomerID         Country
# 1410       2,51         NaN  United Kingdom
# 1411       2,51         NaN  United Kingdom
# 1412       0,85         NaN  United Kingdom
# 1413       1,66         NaN  United Kingdom
# 1414       1,66         NaN  United Kingdom
# ...         ...         ...             ...
# 521695     4,13         NaN  United Kingdom
# 521696     4,13         NaN  United Kingdom
# 521697     4,96         NaN  United Kingdom
# 521698    10,79         NaN  United Kingdom
# 521699  1714,17         NaN  United Kingdom
#
# [132586 rows x 7 columns]

# %%
df.groupby(['Country'])['BillNo'].nunique().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          18669
# Germany                   457
# France                    392
# Belgium                    98
# Netherlands                95
# Spain                      90
# Portugal                   58
# Australia                  57
# Switzerland                54
# Italy                      38
# Sweden                     36
# Norway                     36
# Poland                     19
# Japan                      19
# Austria                    17
# Unspecified                13
# Hong Kong                  11
# Israel                      8
# Iceland                     7
# Singapore                   7
# Greece                      5
# USA                         5
# Malta                       5
# Lithuania                   4
# United Arab Emirates        3
# Bahrain                     3
# Lebanon                     1
# RSA                         1
# Saudi Arabia                1
# Brazil                      1
# Name: BillNo, dtype: int64

# %% [markdown]
# #Veri setimizi birliktelik analizini hazırlıyoruz.

# %%
dfprep = df.groupby(['BillNo','Itemname']).agg({'Quantity':'sum'}).reset_index().pivot(index='BillNo',columns='Itemname').fillna(0)
dfprep.columns = dfprep.columns.droplevel(0)

# %%
dfprep.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-5e411a27b08a> in <cell line: 1>()
# ----> 1 dfprep.head()
#
# NameError: name 'dfprep' is not defined

# %%
dfprep.reset_index(inplace=True)
dfprep.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-c2c0222cb306> in <cell line: 1>()
# ----> 1 dfprep.reset_index(inplace=True)
#       2 dfprep.head()
#
# NameError: name 'dfprep' is not defined

# %%
#total number of items
dfprep.drop(dfprep.columns[0],inplace=True,axis=1)

# %%
dfprep = dfprep.applymap(lambda x: True if x>0 else False)

# %%
dfprep
# Out:
# Itemname  index         *Boombox Ipod Classic  *USB Office Mirror Ball  \
# 0             0  False                  False                    False
# 1             1  False                  False                    False
# 2             2  False                  False                    False
# 3             3  False                  False                    False
# 4             4  False                  False                    False
# ...         ...    ...                    ...                      ...
# 8065       8065  False                  False                    False
# 8066       8066  False                  False                    False
# 8067       8067  False                  False                    False
# 8068       8068  False                  False                    False
# 8069       8069  False                  False                    False
#
# Itemname  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
# ...                          ...                         ...
# 8065                       False                       False
# 8066                       False                       False
# 8067                       False                       False
# 8068                       False                       False
# 8069                       False                       False
#
# Itemname  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# 0                             False                      False
# 1                             False                      False
# 2                             False                      False
# 3                             False                      False
# 4                             False                      False
# ...                             ...                        ...
# 8065                          False                      False
# 8066                          False                      False
# 8067                          False                      False
# 8068                          False                      False
# 8069                          False                      False
#
# Itemname  12 IVORY ROSE PEG PLACE SETTINGS  12 MESSAGE CARDS WITH ENVELOPES  \
# 0                                    False                            False
# 1                                    False                            False
# 2                                    False                            False
# 3                                    False                            False
# 4                                    False                            False
# ...                                    ...                              ...
# 8065                                 False                            False
# 8066                                 False                            False
# 8067                                 False                            False
# 8068                                 False                            False
# 8069                                 False                            False
#
# Itemname  ...  thrown away-can't sell  thrown away-can't sell.  wet/rusty  \
# 0         ...                   False                    False      False
# 1         ...                   False                    False      False
# 2         ...                   False                    False      False
# 3         ...                   False                    False      False
# 4         ...                   False                    False      False
# ...       ...                     ...                      ...        ...
# 8065      ...                   False                    False      False
# 8066      ...                   False                    False      False
# 8067      ...                   False                    False      False
# 8068      ...                   False                    False      False
# 8069      ...                   False                    False      False
#
# Itemname  wrong barcode  wrong barcode (22467)  wrong code  wrong code?  \
# 0                 False                  False       False        False
# 1                 False                  False       False        False
# 2                 False                  False       False        False
# 3                 False                  False       False        False
# 4                 False                  False       False        False
# ...                 ...                    ...         ...          ...
# 8065              False                  False       False        False
# 8066              False                  False       False        False
# 8067              False                  False       False        False
# 8068              False                  False       False        False
# 8069              False                  False       False        False
#
# Itemname  wrongly sold (22719) barcode  wrongly sold as sets  \
# 0                                False                 False
# 1                                False                 False
# 2                                False                 False
# 3                                False                 False
# 4                                False                 False
# ...                                ...                   ...
# 8065                             False                 False
# 8066                             False                 False
# 8067                             False                 False
# 8068                             False                 False
# 8069                             False                 False
#
# Itemname  wrongly sold sets
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 8065                  False
# 8066                  False
# 8067                  False
# 8068                  False
# 8069                  False
#
# [8070 rows x 3428 columns]

# %%
frequent_itemsets = apriori(dfprep, min_support= 0.01, use_colnames=True, max_len = 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-058a0c5e34cc> in <cell line: 1>()
# ----> 1 frequent_itemsets = apriori(dfprep, min_support= 0.01, use_colnames=True, max_len = 2)
#
# NameError: name 'apriori' is not defined

# %%
frequent_itemsets

# %%
rules = association_rules(frequent_itemsets, metric="lift",  min_threshold = 1.5)
rules.shape

# %%
rules
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fcddd86006d9> in <cell line: 1>()
# ----> 1 rules
#
# NameError: name 'rules' is not defined

# %%
rules.sort_values('lift',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8204210fa940> in <cell line: 1>()
# ----> 1 rules.sort_values('lift',ascending=False)
#
# NameError: name 'rules' is not defined

# %%
rules.sort_values('confidence', ascending=False)
# Out:
#                                 antecedents  \
# 170    (BEADED CRYSTAL HEART PINK ON STICK)
# 169   (BEADED CRYSTAL HEART GREEN ON STICK)
# 740                  (HERB MARKER ROSEMARY)
# 714                     (HERB MARKER BASIL)
# 722                    (HERB MARKER CHIVES)
# ...                                     ...
# 414    (WHITE HANGING HEART T-LIGHT HOLDER)
# 1998   (WHITE HANGING HEART T-LIGHT HOLDER)
# 322    (WHITE HANGING HEART T-LIGHT HOLDER)
# 377    (WHITE HANGING HEART T-LIGHT HOLDER)
# 1894   (WHITE HANGING HEART T-LIGHT HOLDER)
#
#                              consequents  antecedent support  \
# 170                     (DOTCOM POSTAGE)            0.013259
# 169                     (DOTCOM POSTAGE)            0.010781
# 740                  (HERB MARKER THYME)            0.016729
# 714                   (HERB MARKER MINT)            0.016481
# 722                   (HERB MARKER MINT)            0.015118
# ...                                  ...                 ...
# 414                 (DOORMAT UNION FLAG)            0.136555
# 1998    (VINTAGE PAISLEY STATIONERY SET)            0.136555
# 322         (CHOCOLATE HOT WATER BOTTLE)            0.136555
# 377     (CREAM CUPID HEARTS COAT HANGER)            0.136555
# 1894  (RETROSPOT HEART HOT WATER BOTTLE)            0.136555
#
#       consequent support   support  confidence       lift  leverage  \
# 170             0.043618  0.013135    0.990654  22.711873  0.012557
# 169             0.043618  0.010657    0.988506  22.662618  0.010187
# 740             0.016976  0.015613    0.933333  54.978102  0.015329
# 714             0.017844  0.015366    0.932331  52.249373  0.015071
# 722             0.017844  0.014002    0.926230  51.907445  0.013733
# ...                  ...       ...         ...        ...       ...
# 414             0.044114  0.010161    0.074410   1.686770  0.004137
# 1998            0.018711  0.010161    0.074410   3.976755  0.007606
# 322             0.031227  0.010161    0.074410   2.382897  0.005897
# 377             0.021933  0.010037    0.073503   3.351226  0.007042
# 1894            0.029492  0.010037    0.073503   2.492298  0.006010
#
#       conviction  zhangs_metric
# 170   102.332838       0.968816
# 169    83.205204       0.966292
# 740    14.745353       0.998515
# 714    14.514085       0.997297
# 722    13.313672       0.995789
# ...          ...            ...
# 414     1.032732       0.471542
# 1998    1.060177       0.866921
# 322     1.046655       0.672125
# 377     1.055661       0.812561
# 1894    1.047502       0.693459
#
# [2028 rows x 10 columns]
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
